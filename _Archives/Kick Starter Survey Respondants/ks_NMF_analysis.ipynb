# %% [markdown]
# ## Importing, cleaning and wrangling

# %%
import pandas as pd
import numpy as np
from pandas.api.types import CategoricalDtype
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.mosaicplot import mosaic

# %%
# import data with a context manager
with open("data_ks.csv") as fp:
    df = pd.read_csv(fp) 

    #names = df['last_name'].tolist()
    
    # Drop unnecessary columns from df
    dropcol = ['accessory_channels', 'submitted_date', 'token']
    df.drop(columns= dropcol, inplace= True)
    
    # convert to categorical data in the df
    catcol = ["age", "gender", "platform", "income", "experience", "rides_per_week", "num_bikes_owned", "bike_cost", "location", "environment", 'accessory_factor' ]
    for col in catcol:
        df[col] = df[col].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1691 entries, 0 to 1690
# Data columns (total 22 columns):
# age                        1691 non-null category
# gender                     1691 non-null category
# platform                   1691 non-null category
# income                     1691 non-null category
# experience                 1691 non-null category
# rides_per_week             1691 non-null category
# bike_type                  1691 non-null object
# num_bikes_owned            1691 non-null category
# bike_cost                  1691 non-null category
# location                   1691 non-null category
# environment                1691 non-null category
# companions                 1691 non-null object
# conditions                 1691 non-null object
# activities                 1691 non-null object
# reasons_to_bike            1691 non-null object
# reasons_to_not_bike        1691 non-null object
# reason_for_smarthalo       1691 non-null object
# has_smarthalo_1            1691 non-null object
# accessory_factor           1690 non-null category
# will_give_more_feedback    1688 non-null object
# email                      1378 non-null object
# bad_column                 1487 non-null object
# dtypes: category(11), object(11)
# memory usage: 169.8+ KB

# %%
for i in catcol:
    print(df[i].value_counts(dropna=False), '\n')
# Out:
# 25-34 years    481
# 35-44 years    472
# 45-54 years    289
# 55+ years      285
# 0-25 years     108
# 45-45 years     56
# Name: age, dtype: int64
#
# Male                 1431
# Female                244
# Prefer not to say       9
# Non-binary              7
# Name: gender, dtype: int64
#
# iOS        962
# Android    729
# Name: platform, dtype: int64
#
# 40,000 - 79,000 / year    573
# 80,000+ / year            564
# 0 - 39,999 / year         301
# Prefer not to say         253
# Name: income, dtype: int64
#
# 8     473
# 7     463
# 6     248
# 9     186
# 5     121
# 10    106
# 4      50
# 3      23
# 2      12
# 1       9
# Name: experience, dtype: int64
#
# 3 or more times a week    942
# 1-2 times a week          520
# Less than once a week     229
# Name: rides_per_week, dtype: int64
#
# 1       682
# 2       588
# 3+      410
# None     11
# Name: num_bikes_owned, dtype: int64
#
# 1000 - 2000      554
# 500 - 1000       490
# 2000 - 4000      309
# 100 - 500        204
# 4000+            122
# Less than 100     12
# Name: bike_cost, dtype: int64
#
# United States     412
# Germany           309
# Canada            205
# United Kingdom    132
# Netherlands       116
#                  ...
# Qatar               1
# Ecuador             1
# Portugal            1
# Paraguay            1
# Lithuania           1
# Name: location, Length: 61, dtype: int64
#
# CITY - urban, dense, etc.               678
# TOWN - neighbourhood, suburban, etc.    568
# RURAL - village, country, etc.          268
# NATURE - mountains, forests, etc.       177
# Name: environment, dtype: int64
#
# It meets all my needs                                                                                                                           1046
# Online reviews                                                                                                                                   303
# Price                                                                                                                                            159
# Friend/family recommendations                                                                                                                     79
# The brand/company                                                                                                                                 49
# Influencer recommendations                                                                                                                        32
# NaN                                                                                                                                                1
# It meets enough of my needs                                                                                                                        1
# Environmentally friendly and durability                                                                                                            1
# Fin                                                                                                                                                1
# Function and form(design)                                                                                                                          1
# Functionality because honestly less is more                                                                                                        1
# Functionality, reviews and quality                                                                                                                 1
# I want it                                                                                                                                          1
# Innovation                                                                                                                                         1
# Innovation. New technology, assists with keeping me safe                                                                                           1
# It must meet my requirements and continue to meet them long-term (no failed hardware or backend shutdowns for an appreciable length of time)       1
# It meets most of my needs                                                                                                                          1
# what is specific need at moment                                                                                                                    1
# Meets needs along with reviews and recommendations                                                                                                 1
# My own opinion and expectation on usefulness                                                                                                       1
# Product quality                                                                                                                                    1
# Quality                                                                                                                                            1
# Reliability                                                                                                                                        1
# Technology built into it.                                                                                                                          1
# quality and function (that's two, I know)                                                                                                          1
# restrictions                                                                                                                                       1
# varies with accessory                                                                                                                              1
# Curiosity                                                                                                                                          1
# Name: accessory_factor, dtype: int64

# %% [markdown]
# ## Exploring ML as analysis tool

# %% [markdown]
# ### Unsupervized learning in Python Chap3 p. 33
# scipy.sparse.csr_matrix

# %%
to_sparse = ['bike_type', 'companions', 'conditions', 'activities', 'reasons_to_bike', 'reasons_to_not_bike', 'reason_for_smarthalo']

print('Number of unique combinaison of answer for each questions', '\n')
for i in to_sparse:
    print('{}:  '.format(i.capitalize()), df[i].nunique())
# Out:
# Number of unique combinaison of answer for each questions
#
# Bike_type:   337
# Companions:   33
# Conditions:   137
# Activities:   750
# Reasons_to_bike:   1016
# Reasons_to_not_bike:   720
# Reason_for_smarthalo:   537

# %% [markdown]
# ### NLP tokenization & sklearn CountVectorizer()

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Instantiate the CountVectorizer: vec
vec = CountVectorizer(tokenizer=lambda x: x.split(', '))  # Object to convert in matrix of token counts 

# Fit to the data
for i in to_sparse:
    vec.fit(df[i]) # Convert df.bike_type to matrix of token
    print(vec.get_feature_names(), '\n')

#Archives
# TOKENS = '(?:[a-zA-Z1-9/-]|\s)' # Take only strings between ',' as token but, lamba function x.split(', ') works better   
# print("There are {} tokens in the dataset".format(len(vec.get_feature_names())))
# Out:
# ['a brompton', 'a foldable bike', 'bike share bike', 'bmx', 'brompton', 'brompton folding bike', 'cargo bike', 'cross bike', 'crossbike', 'crossbike ', 'cruiser / city bike', 'cyclo cross', 'cyclocross', 'dirt/gravel trike', 'dual speed city road bike', 'dutch bike', 'e-bike', 'e-mountainbike', 'e-road bike', 'e-trike', 'elliptigo', 'fat bike', 'floding bikes', 'foldable', 'foldable bike', 'foldie', 'folding bicycle', 'folding bike', 'folding bike ', 'folding bike (brompton)', 'folding bike (dahon mu)', 'folding commuter bike', 'gravel bike', 'halfbike', 'holiday bike', 'hometrainer', 'hybrid bike', 'i have inokim electronic scooter', 'minivero', 'mountain bike', 'polo bike', 'race bike', 'recumbent', 'recumbent trike', 'road bike', 'scooter', 'short frame recumbent', 'single-speed bike', 'spin bike', 'tandem', 'tandem bike', "tandem bike (bike friday 'q')", 'tempo', 'time trial bike', 'tourbike', 'touring bike', 'tracking bike', 'travel bike', 'trekking', 'trekking ', 'trekking bike', 'triathlon', 'triathlon ', 'triathlon bike', 'tricycle', 'urban bike', 'vintage road']
#
# ['i bike alone', 'with a riding pack', 'with family and friends', 'with young children']
#
# ['hot/humid', 'night', 'rain', 'snow/ice', 'temperate']
#
# ['bmx', 'chores / errands', 'commuting', 'exploring', 'feel super cool on a bike and also it’s better for the environment', 'fitness', 'freetime', 'i live in amsterdam', 'i use my bike for everything  :)', 'mobility in the city', 'mountain biking', 'pleasure rides', 'racing', 'school', 'shopping', 'take my kid to a pre-school care', 'touring', 'transportation', 'triathlon', 'work', 'workout']
#
# ['brewery hopping ', 'can use it in the winter!! :)', 'davis', 'driving a car and drinking doesn’t match', 'easy snd faster ', "i don't own a car", 'i don’t have to worry about traffic jams. ', 'i don’t own a car ', 'i have friends/family who also bike', 'i have no option as it’s to expensive to run gas guzzlers in london ', 'i live in amsterdam :)', 'i live in the netherlands', 'i want to be healthy', 'i want to reduce my environmental impact', 'i want to spend time with my family outdoors', 'improve my physic condition', 'in holland everybody rides a bike', 'installing good healthy lifestyle habbits for my children ', 'it takes less time than a car', "it's more convenient", "it's the future", 'it’s cheaper', 'it’s faster', 'it’s more convenient', 'it’s more fun', 'it’s more reliable', 'it’s my hobby/interest', 'it’s my job', 'it’s part of my identity/culture', 'i’m dutch and what can i say... we bike a lot ;-)', 'my car is already in use!', 'my work pays me $$$ to bike instead of drive to work', 'nice way to explore and visit around new places', 'no carpark needed', 'relax / mind reset ', 'the alternative is a bus... i really don’t like the bus']
#
# ["i don't know the way", "i don't want to sweat", 'i feel lazy', 'i have to carry things with me', "it wouldn't be fun", "it's not safe for me", "it's not safe for my bike", "it's too dark", 'the route is too long/steep', "the weather doesn't suit me"]
#
# ['', ' because i am fascinated of the thing', '<kombination of 4 tools', 'a useful tool', 'acctually i intend to try it on my motorbike', 'all above', 'as a fancy gps bike speedometer (my current one is not precise at all)', 'as a gift', 'as a gift ', 'as a gift for my cycle loving in laws', 'as a present', 'because it looks to be well-priced', "because it's cool!", 'because smarthalo 1 was not so good', 'curiosity', 'curious about some new things', 'deux montagnes rem project pushed me to bike from laval to downtown montreal next year', 'espacially the additional light', 'gift', 'gift for a biker who bikes as a mode of transportation', 'great idea', "i bought it for my husband (he's the one that bikes) as a gift", 'i like innovation', "i'm a gadget freak. i hope it will convince me to bicycle more than i currently do.", 'ifttt ', 'in journey cycling metrics like time speed', 'instead of bike computer', 'is usefully', 'love technology ', 'my apple watch broke last year', 'new e-scooter', 'nice device with light on it.', "safer routes… but not for smarthalo's light", 'safest routes)', "so i don't have to look at my phone while riding", 'to encourage me to explore unfamiliar routes/territory', 'to help encourage myself to get back on my bike and ride more. ', 'to help keep my bike safe', 'to help me keep track of my environmental goals', 'to help me keep track of my fitness goals', 'to help me navigate', 'to help me stay safe (nightlight', 'to know speed and distance', 'to substitute my current old polar watch for my bike.', 'to support a small company with a great idea/product', 'to support development in québec ', 'to support new technology', 'want to try it', 'want to try new product', 'when friends use my bike i know it will help them and be safer', 'which is irrelevant to me and most serious cyclists (as we have dedicated lights for biking).']

# %%
# {'col_to_parse': {'value_to_replace': 'replace_with_value'}}
replace_val = {'bike_type': {'gravel bike': 'all road', 'Brompton': 'foldable', 'Brompton folding ': 'foldable', 'folding': 'foldable', 'FALTRAD': 'foldable', 'fat': 'fat bike', 'recumbent trike': 'recumbent', 'speed pedelec (45km/h e-bike)': 'e-bike', 'time-trial race bike': 'road bike', 'touring': 'touring bike'}}
df.bike_type.replace(replace_val, inplace=True)

# %%
vec.fit(df['bike_type'])
vec.get_feature_names()
# Out:
# ['a brompton',
#  'a foldable bike',
#  'bike share bike',
#  'bmx',
#  'brompton',
#  'brompton folding bike',
#  'cargo bike',
#  'cross bike',
#  'crossbike',
#  'crossbike ',
#  'cruiser / city bike',
#  'cyclo cross',
#  'cyclocross',
#  'dirt/gravel trike',
#  'dual speed city road bike',
#  'dutch bike',
#  'e-bike',
#  'e-mountainbike',
#  'e-road bike',
#  'e-trike',
#  'elliptigo',
#  'fat bike',
#  'floding bikes',
#  'foldable',
#  'foldable bike',
#  'foldie',
#  'folding bicycle',
#  'folding bike',
#  'folding bike ',
#  'folding bike (brompton)',
#  'folding bike (dahon mu)',
#  'folding commuter bike',
#  'gravel bike',
#  'halfbike',
#  'holiday bike',
#  'hometrainer',
#  'hybrid bike',
#  'i have inokim electronic scooter',
#  'minivero',
#  'mountain bike',
#  'polo bike',
#  'race bike',
#  'recumbent',
#  'recumbent trike',
#  'road bike',
#  'scooter',
#  'short frame recumbent',
#  'single-speed bike',
#  'spin bike',
#  'tandem',
#  'tandem bike',
#  "tandem bike (bike friday 'q')",
#  'tempo',
#  'time trial bike',
#  'tourbike',
#  'touring bike',
#  'tracking bike',
#  'travel bike',
#  'trekking',
#  'trekking ',
#  'trekking bike',
#  'triathlon',
#  'triathlon ',
#  'triathlon bike',
#  'tricycle',
#  'urban bike',
#  'vintage road']

# %%
df_text = df[to_sparse].apply(lambda x: ", ".join(x), axis=1)
df_text.head()
# Out:
# 0    E-bike, With family and friends, Temperate, Mo...
# 1    Mountain bike, Hybrid bike, Road bike, I bike ...
# 2    Cruiser / City bike, With family and friends, ...
# 3    Road bike, Mountain bike, I bike alone, Night,...
# 4    Road bike, With family and friends, Hot/Humid,...
# dtype: object

# %%
# Instantiate the CountVectorizer: vec
vec = CountVectorizer(tokenizer=lambda x: x.split(', '))  # Object to convert in matrix of token counts 

# Fit to the data
X = vec.fit_transform(df_text) # Convert df.bike_type to matrix of token
print("There are {} tokens in the dataset".format(len(vec.get_feature_names())))
# Out:
# There are 192 tokens in the dataset

# %%
vec.get_feature_names()
# Out:
# ['',
#  ' because i am fascinated of the thing',
#  '<kombination of 4 tools',
#  'a brompton',
#  'a foldable bike',
#  'a useful tool',
#  'acctually i intend to try it on my motorbike',
#  'all above',
#  'as a fancy gps bike speedometer (my current one is not precise at all)',
#  'as a gift',
#  'as a gift ',
#  'as a gift for my cycle loving in laws',
#  'as a present',
#  'because it looks to be well-priced',
#  "because it's cool!",
#  'because smarthalo 1 was not so good',
#  'bike share bike',
#  'bmx',
#  'brewery hopping ',
#  'brompton',
#  'brompton folding bike',
#  'can use it in the winter!! :)',
#  'cargo bike',
#  'chores / errands',
#  'commuting',
#  'cross bike',
#  'crossbike',
#  'crossbike ',
#  'cruiser / city bike',
#  'curiosity',
#  'curious about some new things',
#  'cyclo cross',
#  'cyclocross',
#  'davis',
#  'deux montagnes rem project pushed me to bike from laval to downtown montreal next year',
#  'dirt/gravel trike',
#  'driving a car and drinking doesn’t match',
#  'dual speed city road bike',
#  'dutch bike',
#  'e-bike',
#  'e-mountainbike',
#  'e-road bike',
#  'e-trike',
#  'easy snd faster ',
#  'elliptigo',
#  'espacially the additional light',
#  'exploring',
#  'fat bike',
#  'feel super cool on a bike and also it’s better for the environment',
#  'fitness',
#  'floding bikes',
#  'foldable',
#  'foldable bike',
#  'foldie',
#  'folding bicycle',
#  'folding bike',
#  'folding bike ',
#  'folding bike (brompton)',
#  'folding bike (dahon mu)',
#  'folding commuter bike',
#  'freetime',
#  'gift',
#  'gift for a biker who bikes as a mode of transportation',
#  'gravel bike',
#  'great idea',
#  'halfbike',
#  'holiday bike',
#  'hometrainer',
#  'hot/humid',
#  'hybrid bike',
#  'i bike alone',
#  "i bought it for my husband (he's the one that bikes) as a gift",
#  "i don't know the way",
#  "i don't own a car",
#  "i don't want to sweat",
#  'i don’t have to worry about traffic jams. ',
#  'i don’t own a car ',
#  'i feel lazy',
#  'i have friends/family who also bike',
#  'i have inokim electronic scooter',
#  'i have no option as it’s to expensive to run gas guzzlers in london ',
#  'i have to carry things with me',
#  'i like innovation',
#  'i live in amsterdam',
#  'i live in amsterdam :)',
#  'i live in the netherlands',
#  'i use my bike for everything  :)',
#  'i want to be healthy',
#  'i want to reduce my environmental impact',
#  'i want to spend time with my family outdoors',
#  "i'm a gadget freak. i hope it will convince me to bicycle more than i currently do.",
#  'ifttt ',
#  'improve my physic condition',
#  'in holland everybody rides a bike',
#  'in journey cycling metrics like time speed',
#  'installing good healthy lifestyle habbits for my children ',
#  'instead of bike computer',
#  'is usefully',
#  'it takes less time than a car',
#  "it wouldn't be fun",
#  "it's more convenient",
#  "it's not safe for me",
#  "it's not safe for my bike",
#  "it's the future",
#  "it's too dark",
#  'it’s cheaper',
#  'it’s faster',
#  'it’s more convenient',
#  'it’s more fun',
#  'it’s more reliable',
#  'it’s my hobby/interest',
#  'it’s my job',
#  'it’s part of my identity/culture',
#  'i’m dutch and what can i say... we bike a lot ;-)',
#  'love technology ',
#  'minivero',
#  'mobility in the city',
#  'mountain bike',
#  'mountain biking',
#  'my apple watch broke last year',
#  'my car is already in use!',
#  'my work pays me $$$ to bike instead of drive to work',
#  'new e-scooter',
#  'nice device with light on it.',
#  'nice way to explore and visit around new places',
#  'night',
#  'no carpark needed',
#  'pleasure rides',
#  'polo bike',
#  'race bike',
#  'racing',
#  'rain',
#  'recumbent',
#  'recumbent trike',
#  'relax / mind reset ',
#  'road bike',
#  "safer routes… but not for smarthalo's light",
#  'safest routes)',
#  'school',
#  'scooter',
#  'shopping',
#  'short frame recumbent',
#  'single-speed bike',
#  'snow/ice',
#  "so i don't have to look at my phone while riding",
#  'spin bike',
#  'take my kid to a pre-school care',
#  'tandem',
#  'tandem bike',
#  "tandem bike (bike friday 'q')",
#  'temperate',
#  'tempo',
#  'the alternative is a bus... i really don’t like the bus',
#  'the route is too long/steep',
#  "the weather doesn't suit me",
#  'time trial bike',
#  'to encourage me to explore unfamiliar routes/territory',
#  'to help encourage myself to get back on my bike and ride more. ',
#  'to help keep my bike safe',
#  'to help me keep track of my environmental goals',
#  'to help me keep track of my fitness goals',
#  'to help me navigate',
#  'to help me stay safe (nightlight',
#  'to know speed and distance',
#  'to substitute my current old polar watch for my bike.',
#  'to support a small company with a great idea/product',
#  'to support development in québec ',
#  'to support new technology',
#  'tourbike',
#  'touring',
#  'touring bike',
#  'tracking bike',
#  'transportation',
#  'travel bike',
#  'trekking',
#  'trekking ',
#  'trekking bike',
#  'triathlon',
#  'triathlon ',
#  'triathlon bike',
#  'tricycle',
#  'urban bike',
#  'vintage road',
#  'want to try it',
#  'want to try new product',
#  'when friends use my bike i know it will help them and be safer',
#  'which is irrelevant to me and most serious cyclists (as we have dedicated lights for biking).',
#  'with a riding pack',
#  'with family and friends',
#  'with young children',
#  'work',
#  'workout']

# %%
# X_train, X_test, y_train, y_test = train_test_split(vec, random_state=456)
df_matrix = pd.DataFrame(X.toarray(), columns=vec.get_feature_names())
# Out:
#   (0, 39)	1
#   (0, 188)	1
#   (0, 150)	1
#   (0, 118)	1
#   (0, 169)	1
#   (0, 49)	1
#   (0, 109)	1
#   (0, 87)	1
#   (0, 108)	1
#   (0, 77)	1
#   (0, 154)	1
#   (0, 158)	1
#   (0, 162)	1
#   (0, 137)	1
#   (0, 161)	1
#   (1, 150)	1
#   (1, 49)	1
#   (1, 87)	1
#   (1, 108)	1
#   (1, 154)	1
#   (1, 161)	1
#   (1, 117)	1
#   (1, 69)	1
#   (1, 135)	1
#   (1, 70)	1
#   :	:
#   (1689, 106)	1
#   (1689, 107)	1
#   (1689, 88)	1
#   (1689, 101)	1
#   (1689, 144)	1
#   (1689, 68)	1
#   (1689, 172)	1
#   (1689, 81)	1
#   (1689, 104)	1
#   (1690, 188)	1
#   (1690, 150)	1
#   (1690, 118)	1
#   (1690, 77)	1
#   (1690, 154)	1
#   (1690, 117)	1
#   (1690, 127)	1
#   (1690, 78)	1
#   (1690, 110)	1
#   (1690, 14)	1
#   (1690, 144)	1
#   (1690, 131)	1
#   (1690, 112)	1
#   (1690, 81)	1
#   (1690, 74)	1
#   (1690, 142)	1

# %% [markdown]
# ### Unsupervized learning in Python Chap1 p. 31
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaler.fit(samples)
# StandardScaler(copy=True, with_mean=True, with_std=True)
# samples_scaled = scaler.transform(samples)

# %% [markdown]
# ### Unsupervized learning in Python Chap4 p. 7
# NMF with word frequency array

# %%
from sklearn.decomposition import NMF

matrix = X.toarray()
model = NMF(n_components=5)
model.fit(matrix)
nmf_features = model.transform(matrix)

# %%
#nmf_features
#df_nmf = pd.DataFrame(nmf_features,index=names)
#df_nmf.loc['Denis']

# %%
nmf_features
# Out:
# array([[0.12231073, 0.02323385, 0.20427926, 0.12573124, 0.        ],
#        [0.15423672, 0.26036853, 0.00738726, 0.18873421, 0.05855126],
#        [0.00259247, 0.14280095, 0.        , 0.07509475, 0.24108659],
#        ...,
#        [0.09357699, 0.15245619, 0.02110561, 0.03529629, 0.29160295],
#        [0.19852674, 0.26982555, 0.21820291, 0.        , 0.11330575],
#        [0.12180771, 0.        , 0.        , 0.18326583, 0.07428773]])

# %%
# Create a DataFrame: components_df
components_df = pd.DataFrame(model.components_, columns=vec.get_feature_names())

# Print the shape of the DataFrame
print(components_df.shape)

for x in range(0,components_df.shape[0]):
    print("\nPersona "+str(x))
    print("==========")
    component = components_df.iloc[x,:]
    print(component.nlargest(50))
    print("\n")
# Out:
# (5, 192)
#
# Persona 0
# ==========
# the weather doesn't suit me                                                            3.966413
# temperate                                                                              2.784269
# i want to be healthy                                                                   2.559829
# i bike alone                                                                           2.521009
# because it's cool!                                                                     2.384590
# to help me navigate                                                                    2.306264
# so i don't have to look at my phone while riding                                       2.263653
# pleasure rides                                                                         1.981890
# it's not safe for me                                                                   1.909435
# fitness                                                                                1.717054
# i have to carry things with me                                                         1.663924
# i feel lazy                                                                            1.582488
# to help me keep track of my fitness goals                                              1.439928
# it's too dark                                                                          1.365900
# the route is too long/steep                                                            1.227880
# it's not safe for my bike                                                              1.193141
# hybrid bike                                                                            1.029289
# it wouldn't be fun                                                                     0.927225
# hot/humid                                                                              0.883919
# it’s more fun                                                                          0.835709
# i don't want to sweat                                                                  0.739474
# to help keep my bike safe                                                              0.688335
# i want to reduce my environmental impact                                               0.684504
# commuting                                                                              0.639044
# e-bike                                                                                 0.532262
# cruiser / city bike                                                                    0.488269
# with family and friends                                                                0.456406
# transportation                                                                         0.440931
# it’s my hobby/interest                                                                 0.330728
# road bike                                                                              0.277605
# to help me keep track of my environmental goals                                        0.265839
# i don't know the way                                                                   0.263442
# night                                                                                  0.253290
# chores / errands                                                                       0.127553
# with young children                                                                    0.115858
# bike share bike                                                                        0.037236
# folding bike                                                                           0.021495
# cyclocross                                                                             0.014372
# triathlon                                                                              0.008300
# recumbent trike                                                                        0.006995
# to support a small company with a great idea/product                                   0.006221
# triathlon                                                                              0.005709
# great idea                                                                             0.005533
# want to try it                                                                         0.005533
# as a gift                                                                              0.005516
# as a present                                                                           0.005193
# tracking bike                                                                          0.005087
# i'm a gadget freak. i hope it will convince me to bicycle more than i currently do.    0.005084
# installing good healthy lifestyle habbits for my children                              0.004965
# e-trike                                                                                0.004942
# Name: 0, dtype: float64
#
#
#
# Persona 1
# ==========
# it’s faster                                                           2.970666
# it’s more convenient                                                  2.920071
# it’s cheaper                                                          2.714757
# commuting                                                             2.602455
# i want to reduce my environmental impact                              2.481100
# transportation                                                        2.401635
# chores / errands                                                      2.113626
# it’s more reliable                                                    1.916008
# i bike alone                                                          1.631222
# it’s more fun                                                         1.378518
# to help me navigate                                                   1.220838
# work                                                                  1.217513
# temperate                                                             1.214233
# i want to be healthy                                                  1.066268
# it’s part of my identity/culture                                      0.996159
# so i don't have to look at my phone while riding                      0.943730
# cruiser / city bike                                                   0.906360
# the route is too long/steep                                           0.848704
# pleasure rides                                                        0.819812
# road bike                                                             0.678878
# i don't want to sweat                                                 0.668224
# the weather doesn't suit me                                           0.647627
# because it's cool!                                                    0.636992
# to help keep my bike safe                                             0.599158
# night                                                                 0.560473
# touring                                                               0.513728
# single-speed bike                                                     0.457722
# bike share bike                                                       0.455961
# i have to carry things with me                                        0.324141
# e-bike                                                                0.263330
# hybrid bike                                                           0.260442
# it's not safe for my bike                                             0.244450
# fitness                                                               0.233760
# it's not safe for me                                                  0.159946
# gravel bike                                                           0.158060
# cargo bike                                                            0.117534
# with young children                                                   0.052274
# it’s my hobby/interest                                                0.042376
# i feel lazy                                                           0.038296
# folding bike                                                          0.027367
# brompton                                                              0.020483
# to help me keep track of my environmental goals                       0.013519
# feel super cool on a bike and also it’s better for the environment    0.006745
# touring bike                                                          0.006146
# curiosity                                                             0.006027
# it's the future                                                       0.005963
# <kombination of 4 tools                                               0.005857
# espacially the additional light                                       0.005857
# mobility in the city                                                  0.005857
# halfbike                                                              0.005774
# Name: 1, dtype: float64
#
#
#
# Persona 2
# ==========
# safest routes)                                            4.651616
# to help me stay safe (nightlight                          4.651616
# to help keep my bike safe                                 2.670847
# it's not safe for me                                      1.208466
# to help me navigate                                       0.800044
# to help me keep track of my environmental goals           0.732721
# it's not safe for my bike                                 0.654693
# to help me keep track of my fitness goals                 0.575372
# so i don't have to look at my phone while riding          0.542157
# night                                                     0.491523
# i want to reduce my environmental impact                  0.427768
# pleasure rides                                            0.369373
# with family and friends                                   0.353237
# it’s more fun                                             0.247535
# i don't know the way                                      0.235658
# temperate                                                 0.224130
# i have friends/family who also bike                       0.207156
# transportation                                            0.144257
# hybrid bike                                               0.121276
# the route is too long/steep                               0.118559
# i want to be healthy                                      0.117680
# i feel lazy                                               0.102417
# chores / errands                                          0.085945
# it’s cheaper                                              0.081828
# with young children                                       0.076944
# i bike alone                                              0.072660
# work                                                      0.054550
# i have to carry things with me                            0.035211
# bike share bike                                           0.028124
# with a riding pack                                        0.022115
# foldable bike                                             0.017650
# fat bike                                                  0.012842
# trekking                                                  0.006972
# foldie                                                    0.006095
# driving a car and drinking doesn’t match                  0.006010
#                                                           0.005596
# a useful tool                                             0.005596
# gift for a biker who bikes as a mode of transportation    0.005596
# i have inokim electronic scooter                          0.005558
# dirt/gravel trike                                         0.005020
# exploring                                                 0.005020
# folding bike (dahon mu)                                   0.004987
# davis                                                     0.004847
# my work pays me $$$ to bike instead of drive to work      0.004830
# crossbike                                                 0.004722
# i live in amsterdam                                       0.004678
# i live in amsterdam :)                                    0.004678
# i use my bike for everything  :)                          0.004678
# floding bikes                                             0.004664
# nice device with light on it.                             0.004644
# Name: 2, dtype: float64
#
#
#
# Persona 3
# ==========
# it’s my hobby/interest                               4.125725
# fitness                                              2.764830
# with family and friends                              2.753745
# road bike                                            2.566530
# it’s more fun                                        2.411405
# touring                                              2.358971
# mountain bike                                        2.311985
# i have friends/family who also bike                  2.255551
# pleasure rides                                       2.143844
# mountain biking                                      1.876887
# i want to be healthy                                 1.568388
# temperate                                            1.290822
# it’s part of my identity/culture                     1.206554
# to help me keep track of my fitness goals            1.130200
# because it's cool!                                   1.057089
# it's not safe for my bike                            0.972698
# to help me navigate                                  0.822067
# racing                                               0.806131
# gravel bike                                          0.729904
# with a riding pack                                   0.676213
# it wouldn't be fun                                   0.652960
# it's not safe for me                                 0.557731
# so i don't have to look at my phone while riding     0.469057
# it's too dark                                        0.380338
# i want to reduce my environmental impact             0.321303
# to help keep my bike safe                            0.243417
# single-speed bike                                    0.233659
# to help me keep track of my environmental goals      0.172615
# hot/humid                                            0.164268
# chores / errands                                     0.133082
# transportation                                       0.123940
# with young children                                  0.088534
# i feel lazy                                          0.071348
# work                                                 0.061165
# cargo bike                                           0.046874
# bmx                                                  0.034004
# bike share bike                                      0.030710
# tandem                                               0.019434
# the weather doesn't suit me                          0.012192
# because it looks to be well-priced                   0.009269
# i don't own a car                                    0.009269
# tandem bike (bike friday 'q')                        0.008990
# i’m dutch and what can i say... we bike a lot ;-)    0.007710
# travel bike                                          0.007165
# fat bike                                             0.006909
# want to try new product                              0.006659
# i want to spend time with my family outdoors         0.006211
# nice way to explore and visit around new places      0.005911
# curious about some new things                        0.005426
# race bike                                            0.005415
# Name: 3, dtype: float64
#
#
#
# Persona 4
# ==========
# rain                                                                                             3.448508
# hot/humid                                                                                        3.359992
# night                                                                                            3.219897
# i bike alone                                                                                     1.703811
# snow/ice                                                                                         1.676140
# temperate                                                                                        1.296645
# i want to be healthy                                                                             1.183293
# because it's cool!                                                                               1.127158
# so i don't have to look at my phone while riding                                                 0.929735
# commuting                                                                                        0.823765
# to help me navigate                                                                              0.761830
# transportation                                                                                   0.722571
# pleasure rides                                                                                   0.689309
# work                                                                                             0.650636
# i feel lazy                                                                                      0.616711
# i have to carry things with me                                                                   0.516019
# fitness                                                                                          0.462964
# hybrid bike                                                                                      0.432481
# with young children                                                                              0.380615
# to help me keep track of my fitness goals                                                        0.362516
# i want to reduce my environmental impact                                                         0.361940
# it’s part of my identity/culture                                                                 0.305287
# to help me keep track of my environmental goals                                                  0.294605
# e-bike                                                                                           0.264888
# mountain bike                                                                                    0.212560
# cruiser / city bike                                                                              0.209936
# it's not safe for me                                                                             0.202590
# chores / errands                                                                                 0.130431
# it’s more fun                                                                                    0.128218
# cargo bike                                                                                       0.123652
# gravel bike                                                                                      0.093049
# it’s faster                                                                                      0.009291
# as a fancy gps bike speedometer (my current one is not precise at all)                           0.007223
#  because i am fascinated of the thing                                                            0.006978
# the route is too long/steep                                                                      0.006897
# to know speed and distance                                                                       0.006634
# i don’t have to worry about traffic jams.                                                        0.006593
# tourbike                                                                                         0.006586
# folding bike                                                                                     0.006540
# folding bicycle                                                                                  0.006491
# tricycle                                                                                         0.006486
# cross bike                                                                                       0.006306
# travel bike                                                                                      0.005054
# foldable                                                                                         0.004552
# safer routes… but not for smarthalo's light                                                      0.004543
# which is irrelevant to me and most serious cyclists (as we have dedicated lights for biking).    0.004543
# crossbike                                                                                        0.004481
# touring bike                                                                                     0.004079
# tandem bike                                                                                      0.004062
# i live in the netherlands                                                                        0.003913
# Name: 4, dtype: float64

# %%
components_df.head()
# Out:
#               because i am fascinated of the thing  <kombination of 4 tools  \
# 0  0.000000                               0.000000                 0.000000
# 1  0.000000                               0.000000                 0.005857
# 2  0.005596                               0.000000                 0.000000
# 3  0.001060                               0.000000                 0.000000
# 4  0.000000                               0.006978                 0.000000
#
#    a brompton  a foldable bike  a useful tool  \
# 0    0.000000         0.000000       0.000000
# 1    0.005254         0.005254       0.000000
# 2    0.001145         0.001145       0.005596
# 3    0.000000         0.000000       0.001060
# 4    0.000000         0.000000       0.000000
#
#    acctually i intend to try it on my motorbike  all above  \
# 0                                      0.000000   0.002037
# 1                                      0.002176   0.000000
# 2                                      0.002191   0.000000
# 3                                      0.000000   0.000000
# 4                                      0.000000   0.000000
#
#    as a fancy gps bike speedometer (my current one is not precise at all)  \
# 0                                           0.000000
# 1                                           0.000000
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.007223
#
#    as a gift  ...  vintage road  want to try it  want to try new product  \
# 0   0.002375  ...      0.002109        0.005533                 0.000427
# 1   0.000000  ...      0.000000        0.000000                 0.000000
# 2   0.000000  ...      0.004207        0.000000                 0.000000
# 3   0.000000  ...      0.000581        0.001229                 0.006659
# 4   0.001529  ...      0.000000        0.000000                 0.000000
#
#    when friends use my bike i know it will help them and be safer  \
# 0                                           0.000000
# 1                                           0.005238
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.000000
#
#    which is irrelevant to me and most serious cyclists (as we have dedicated lights for biking).  \
# 0                                           0.000000
# 1                                           0.000539
# 2                                           0.000000
# 3                                           0.000000
# 4                                           0.004543
#
#    with a riding pack  with family and friends  with young children      work  \
# 0            0.000000                 0.456406             0.115858  0.000000
# 1            0.000000                 0.000000             0.052274  1.217513
# 2            0.022115                 0.353237             0.076944  0.054550
# 3            0.676213                 2.753745             0.088534  0.061165
# 4            0.000000                 0.000000             0.380615  0.650636
#
#     workout
# 0  0.000000
# 1  0.001758
# 2  0.003752
# 3  0.000745
# 4  0.000000
#
# [5 rows x 192 columns]

# %%
from sklearn.preprocessing import normalize

# Normalize the NMF features: norm_features
norm_features = normalize(nmf_features)

# Create a DataFrame: df
dfpersona = pd.DataFrame(norm_features, index=names)

# Select the row corresponding to 'Cristiano Ronaldo': article
persona = dfpersona.loc['Haywood']

# Compute the dot products: similarities
similarities = dfpersona.dot(persona)

# Display those with the largest cosine similarity
print(similarities.nlargest(20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-81e79d9c716c> in <module>
#       5
#       6 # Create a DataFrame: df
# ----> 7 dfpersona = pd.DataFrame(norm_features, index=names)
#       8
#       9 # Select the row corresponding to 'Cristiano Ronaldo': article
#
# NameError: name 'names' is not defined
