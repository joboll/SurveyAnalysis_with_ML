# %% [markdown]
# ## Importing, cleaning, and wrangling data

# %%
import pandas as pd
import numpy as np
from pandas.api.types import CategoricalDtype
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.mosaicplot import mosaic

# %%
# import data with a context manager
with open("data_ks.csv") as fp:
    df = pd.read_csv(fp) 
    names = df['token'].tolist()

# convert to categorical data in the df
catcol = ["age", "gender", "platform", "income", "experience", "rides_per_week", "num_bikes_owned", "bike_cost", "location", "environment", 'accessory_factor' ]
for col in catcol:
    df[col] = df[col].astype('category')

print(df.info())
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1691 entries, 0 to 1690
# Data columns (total 25 columns):
# age                        1691 non-null category
# gender                     1691 non-null category
# platform                   1691 non-null category
# income                     1691 non-null category
# experience                 1691 non-null category
# rides_per_week             1691 non-null category
# bike_type                  1691 non-null object
# num_bikes_owned            1691 non-null category
# bike_cost                  1691 non-null category
# location                   1691 non-null category
# environment                1691 non-null category
# companions                 1691 non-null object
# conditions                 1691 non-null object
# activities                 1691 non-null object
# reasons_to_bike            1691 non-null object
# reasons_to_not_bike        1691 non-null object
# reason_for_smarthalo       1691 non-null object
# has_smarthalo_1            1691 non-null object
# accessory_channels         1690 non-null object
# accessory_factor           1690 non-null category
# will_give_more_feedback    1688 non-null object
# email                      1378 non-null object
# bad_column                 1487 non-null object
# submitted_date             1691 non-null object
# token                      1691 non-null object
# dtypes: category(11), object(14)
# memory usage: 209.4+ KB
# None
# (1691, 25)

# %%
for i in catcol:
    print(df[i].value_counts(dropna=False), '\n')
# Out:
# 25-34 years    481
# 35-44 years    472
# 45-54 years    289
# 55+ years      285
# 0-25 years     108
# 45-45 years     56
# Name: age, dtype: int64
#
# Male                 1431
# Female                244
# Prefer not to say       9
# Non-binary              7
# Name: gender, dtype: int64
#
# iOS        962
# Android    729
# Name: platform, dtype: int64
#
# 40,000 - 79,000 / year    573
# 80,000+ / year            564
# 0 - 39,999 / year         301
# Prefer not to say         253
# Name: income, dtype: int64
#
# 8     473
# 7     463
# 6     248
# 9     186
# 5     121
# 10    106
# 4      50
# 3      23
# 2      12
# 1       9
# Name: experience, dtype: int64
#
# 3 or more times a week    942
# 1-2 times a week          520
# Less than once a week     229
# Name: rides_per_week, dtype: int64
#
# 1       682
# 2       588
# 3+      410
# None     11
# Name: num_bikes_owned, dtype: int64
#
# 1000 - 2000      554
# 500 - 1000       490
# 2000 - 4000      309
# 100 - 500        204
# 4000+            122
# Less than 100     12
# Name: bike_cost, dtype: int64
#
# United States     412
# Germany           309
# Canada            205
# United Kingdom    132
# Netherlands       116
#                  ...
# Qatar               1
# Ecuador             1
# Portugal            1
# Paraguay            1
# Lithuania           1
# Name: location, Length: 61, dtype: int64
#
# CITY - urban, dense, etc.               678
# TOWN - neighbourhood, suburban, etc.    568
# RURAL - village, country, etc.          268
# NATURE - mountains, forests, etc.       177
# Name: environment, dtype: int64
#
# It meets all my needs                                                                                                                           1046
# Online reviews                                                                                                                                   303
# Price                                                                                                                                            159
# Friend/family recommendations                                                                                                                     79
# The brand/company                                                                                                                                 49
# Influencer recommendations                                                                                                                        32
# NaN                                                                                                                                                1
# It meets enough of my needs                                                                                                                        1
# Environmentally friendly and durability                                                                                                            1
# Fin                                                                                                                                                1
# Function and form(design)                                                                                                                          1
# Functionality because honestly less is more                                                                                                        1
# Functionality, reviews and quality                                                                                                                 1
# I want it                                                                                                                                          1
# Innovation                                                                                                                                         1
# Innovation. New technology, assists with keeping me safe                                                                                           1
# It must meet my requirements and continue to meet them long-term (no failed hardware or backend shutdowns for an appreciable length of time)       1
# It meets most of my needs                                                                                                                          1
# what is specific need at moment                                                                                                                    1
# Meets needs along with reviews and recommendations                                                                                                 1
# My own opinion and expectation on usefulness                                                                                                       1
# Product quality                                                                                                                                    1
# Quality                                                                                                                                            1
# Reliability                                                                                                                                        1
# Technology built into it.                                                                                                                          1
# quality and function (that's two, I know)                                                                                                          1
# restrictions                                                                                                                                       1
# varies with accessory                                                                                                                              1
# Curiosity                                                                                                                                          1
# Name: accessory_factor, dtype: int64

# %% [markdown]
# ## Segmentation/Filtering
#
# This section creates a filtered set of data that we will compare against the baseline.

# %% [markdown]
# ### Filter Criteria
#
# This is where we set the filter criteria that will be used in all the output sections below

# %%
#this block is used to segment by categorical dimensions
#segment_text = 'United States'
#segment_df = df[df.location==segment_text]
#segment_text = '45-54 years'
#segment_df = df[df.age==segment_text]

# this block is used to segment by multi-select dimensions
#segment_text = 'Transportation'
#segment_df = df[df['activities'].str.contains(segment_text)]
segment_text = 'don\'t have to look at my phone '
segment_df = df[df['reason_for_smarthalo'].str.contains(segment_text)]

segment_df.shape

#POST: segment_df contains the filtered data we will be outputting below
#POST: segment_text contains outputable text that will be used below
# Out:
# (1158, 25)

# %% [markdown]
# ## Categorical Data Output

# %%
#vars for output
precision = 2
output_data = []

for category in catcol:
    all_values = df[category].value_counts(normalize=True, sort=False)
    segment_values = segment_df[category].value_counts(normalize=True, sort=False)

    for i in range(0, len(all_values)):
        label = "{}:{}".format(category,all_values.index[i]) 
        cat_diff = round((segment_values[i]-all_values[i])/all_values[i]*100, precision)
        formatted_all = round(all_values[i]*100, precision)
        formatted_segment = round(segment_values[i]*100, precision)
        
        output_data.append([label, formatted_all, formatted_segment, cat_diff])


segment_category_df = pd.DataFrame(output_data, columns=['category', '% All', "% {}".format(segment_text), '% difference'])
#segment_category_df.to_csv('segment_category_output.csv', index = False)
print(segment_category_df.to_string())
# Out:
#                                               category  % All  % don't have to look at my phone   % difference
# 0                                       age:0-25 years   6.39                               6.65          4.11
# 1                                      age:25-34 years  28.44                              31.17          9.60
# 2                                      age:35-44 years  27.91                              28.41          1.79
# 3                                      age:45-45 years   3.31                               3.11         -6.13
# 4                                      age:45-54 years  17.09                              15.03        -12.08
# 5                                        age:55+ years  16.85                              15.63         -7.26
# 6                                        gender:Female  14.43                              14.59          1.14
# 7                                          gender:Male  84.62                              84.37         -0.30
# 8                                    gender:Non-binary   0.41                               0.52         25.17
# 9                             gender:Prefer not to say   0.53                               0.52         -2.65
# 10                                    platform:Android  43.11                              43.70          1.36
# 11                                        platform:iOS  56.89                              56.30         -1.03
# 12                            income:0 - 39,999 / year  17.80                              19.17          7.70
# 13                       income:40,000 - 79,000 / year  33.89                              34.20          0.92
# 14                               income:80,000+ / year  33.35                              33.07         -0.84
# 15                            income:Prefer not to say  14.96                              13.56         -9.38
# 16                                        experience:1   0.53                               0.26        -51.32
# 17                                        experience:2   0.53                               0.26        -51.32
# 18                                        experience:3   0.71                               0.69         -2.65
# 19                                        experience:4   1.36                               1.47          7.93
# 20                                        experience:5   2.96                               2.85         -3.62
# 21                                        experience:6   7.16                               6.30        -11.90
# 22                                        experience:7  14.67                              14.08         -4.02
# 23                                        experience:8  27.38                              28.41          3.76
# 24                                        experience:9  27.97                              27.81         -0.59
# 25                                       experience:10  11.00                              11.74          6.77
# 26                     rides_per_week:1-2 times a week  30.75                              30.57         -0.59
# 27               rides_per_week:3 or more times a week  55.71                              55.87          0.30
# 28                rides_per_week:Less than once a week  13.54                              13.56          0.12
# 29                                   num_bikes_owned:1  40.33                              42.31          4.92
# 30                                   num_bikes_owned:2  34.77                              34.28         -1.41
# 31                                  num_bikes_owned:3+  24.25                              22.71         -6.33
# 32                                num_bikes_owned:None   0.65                               0.69          6.20
# 33                                 bike_cost:100 - 500  12.06                              11.66         -3.36
# 34                               bike_cost:1000 - 2000  32.76                              34.02          3.85
# 35                               bike_cost:2000 - 4000  18.27                              17.10         -6.43
# 36                                     bike_cost:4000+   7.21                               6.65         -7.84
# 37                                bike_cost:500 - 1000  28.98                              29.97          3.41
# 38                             bike_cost:Less than 100   0.71                               0.60        -14.82
# 39                                  location:Australia   3.49                               3.80          8.90
# 40                                    location:Austria   1.36                               1.64         20.63
# 41                                    location:Belgium   2.07                               2.07          0.13
# 42                                     location:Brazil   0.35                               0.17        -51.32
# 43                                   location:Bulgaria   0.06                               0.00       -100.00
# 44                                     location:Canada  12.12                              12.78          5.42
# 45                                      location:Chile   0.30                               0.17        -41.59
# 46                                      location:China   0.06                               0.00       -100.00
# 47                                   location:Colombia   0.18                               0.09        -51.32
# 48                                 location:Costa Rica   0.06                               0.09         46.03
# 49                                    location:Croatia   0.18                               0.26         46.03
# 50                                     location:Cyprus   0.06                               0.00       -100.00
# 51                             location:Czech Republic   0.65                               0.69          6.20
# 52                                    location:Denmark   2.72                               3.02         11.11
# 53                                    location:Ecuador   0.06                               0.09         46.03
# 54                                    location:Estonia   0.18                               0.17         -2.65
# 55                                    location:Finland   0.71                               0.60        -14.82
# 56                                     location:France   3.43                               3.89         13.30
# 57                                    location:Germany  18.27                              17.70         -3.12
# 58                                     location:Greece   0.24                               0.26          9.52
# 59                                  location:Hong Kong   0.12                               0.17         46.03
# 60                                    location:Hungary   0.41                               0.52         25.17
# 61                                    location:Iceland   0.18                               0.26         46.03
# 62                                      location:India   0.24                               0.17        -26.99
# 63                                  location:Indonesia   0.06                               0.09         46.03
# 64                                    location:Ireland   0.65                               0.52        -20.35
# 65                                     location:Israel   0.24                               0.26          9.52
# 66                                      location:Italy   1.24                               1.30          4.31
# 67                                      location:Japan   0.89                               0.78        -12.38
# 68                               location:Korea, South   0.35                               0.17        -51.32
# 69                                  location:Lithuania   0.06                               0.00       -100.00
# 70                                 location:Luxembourg   0.18                               0.26         46.03
# 71                                   location:Malaysia   0.12                               0.09        -26.99
# 72                                     location:Mexico   0.53                               0.60         13.58
# 73                                location:Netherlands   6.86                               6.65         -3.07
# 74                                location:New Zealand   0.53                               0.43        -18.87
# 75                                     location:Norway   0.89                               0.95          7.09
# 76                                   location:Paraguay   0.06                               0.09         46.03
# 77                                       location:Peru   0.12                               0.09        -26.99
# 78                                     location:Poland   0.53                               0.69         29.80
# 79                                   location:Portugal   0.06                               0.00       -100.00
# 80                                      location:Qatar   0.06                               0.09         46.03
# 81                                    location:Romania   0.24                               0.26          9.52
# 82                                     location:Russia   0.06                               0.09         46.03
# 83                                     location:Serbia   0.06                               0.09         46.03
# 84                                  location:Singapore   0.77                               0.78          1.10
# 85                                   location:Slovakia   0.06                               0.09         46.03
# 86                                   location:Slovenia   0.18                               0.26         46.03
# 87                               location:South Africa   0.06                               0.00       -100.00
# 88                                location:South Korea   0.12                               0.09        -26.99
# 89                                      location:Spain   0.95                               0.78        -17.86
# 90                                  location:Sri Lanka   0.06                               0.00       -100.00
# 91                                     location:Sweden   1.77                               1.64         -7.52
# 92                                location:Switzerland   2.01                               1.21        -39.87
# 93                                     location:Taiwan   0.18                               0.17         -2.65
# 94                                   location:Thailand   0.12                               0.00       -100.00
# 95                                     location:Turkey   0.06                               0.09         46.03
# 96                                    location:Ukraine   0.12                               0.09        -26.99
# 97                       location:United Arab Emirates   0.12                               0.09        -26.99
# 98                             location:United Kingdom   7.81                               7.94          1.78
# 99                              location:United States  24.36                              24.70          1.37
# 100              environment:CITY - urban, dense, etc.  40.09                              43.09          7.47
# 101      environment:NATURE - mountains, forests, etc.  10.47                               8.89        -15.02
# 102         environment:RURAL - village, country, etc.  15.85                              15.98          0.80
# 103   environment:TOWN - neighbourhood, suburban, etc.  33.59                              32.04         -4.62
# 104                         accessory_factor:Curiosity   0.06                               0.09         45.94
# 105  accessory_factor:Environmentally friendly and ...   0.06                               0.09         45.94
# 106                               accessory_factor:Fin   0.06                               0.00       -100.00
# 107     accessory_factor:Friend/family recommendations   4.67                               4.58         -2.09
# 108         accessory_factor:Function and form(design)   0.06                               0.09         45.94
# 109  accessory_factor:Functionality because honestl...   0.06                               0.00       -100.00
# 110  accessory_factor:Functionality, reviews and qu...   0.06                               0.09         45.94
# 111                         accessory_factor:I want it   0.06                               0.00       -100.00
# 112        accessory_factor:Influencer recommendations   1.89                               1.90          0.33
# 113                        accessory_factor:Innovation   0.06                               0.00       -100.00
# 114  accessory_factor:Innovation. New technology, a...   0.06                               0.00       -100.00
# 115             accessory_factor:It meets all my needs  61.89                              61.92          0.04
# 116       accessory_factor:It meets enough of my needs   0.06                               0.09         45.94
# 117        accessory_factor:It meets most of my needs    0.06                               0.00       -100.00
# 118  accessory_factor:It must meet my requirements ...   0.06                               0.00       -100.00
# 119  accessory_factor:Meets needs along with review...   0.06                               0.00       -100.00
# 120  accessory_factor:My own opinion and expectatio...   0.06                               0.00       -100.00
# 121                    accessory_factor:Online reviews  17.93                              18.74          4.52
# 122                             accessory_factor:Price   9.41                               9.24         -1.79
# 123                   accessory_factor:Product quality   0.06                               0.09         45.94
# 124                           accessory_factor:Quality   0.06                               0.09         45.94
# 125                       accessory_factor:Reliability   0.06                               0.00       -100.00
# 126        accessory_factor:Technology built into it.    0.06                               0.00       -100.00
# 127                 accessory_factor:The brand/company   2.90                               2.76         -4.69
# 128  accessory_factor:quality and function (that's ...   0.06                               0.09         45.94
# 129                     accessory_factor:restrictions    0.06                               0.09         45.94
# 130             accessory_factor:varies with accessory   0.06                               0.09         45.94
# 131   accessory_factor:what is specific need at moment   0.06                               0.00       -100.00

# %% [markdown]
# ## Multi-Select Data Output

# %%
#output vars
segment_count = segment_df.shape[0]
all_count = df.shape[0]
output_data = []

def output_multi_select_counts(option_list, segment_df, all_df, column_name):
    output_data = []
    segment_row_count = segment_df.shape[0]
    all_row_count = all_df.shape[0]
    
    for x in range(0, len(option_list)):
        option = option_list[x]
        segment_count = 0
        segment_percent = 0
        all_count = 0
        all_percent = 0
        difference_percent = 0
        
        #if we have the values, fill them in, otherwise use the zeroes above
        try:
            all_count = all_df[column_name].str.contains(option).value_counts()[True]
            all_percent = round(all_count/all_row_count*100, 2)
            segment_count = segment_df[column_name].str.contains(option).value_counts()[True]
            segment_percent = round(segment_count/segment_row_count*100, 2)
            difference_percent = round((segment_percent-all_percent)/all_percent*100,2)
        except KeyError: 
            pass
        
        output_data.append([option, all_count, segment_count, all_percent, segment_percent, difference_percent])
    
    segment_multi_df = pd.DataFrame(output_data, columns=[column_name, 'all count', 'segment count', "all %", "segment %", "difference %"])
    #segment_multi_df.to_csv('segment_multi_{}_output.csv'.format(column_name), index = False)
    print(segment_multi_df.to_string())
    

'''
The following values are just grabbed from the surveys.  I could probably use a CountVectorizer to do it in a more scalable way
'''

bike_types = ['Road bike', 'Mountain bike', 'Hybrid bike', 'Bike share bike', 'E-bike', 'Cruiser / City bike', 'Cargo bike', 'Single-speed bike', 'Gravel bike']
companions = ['I bike alone', 'With family and friends', 'With young children', 'With a riding pack']
conditions = ['Temperate', 'Hot/Humid', 'Rain', 'Snow/Ice', 'Night']
activities = ['Commuting', 'Chores / Errands', 'Work', 'Transportation', 'Mountain biking', 'Touring', 'Racing', 'Fitness', 'BMX', 'Pleasure rides']
reasons_to_bike = ['convenient', 'reliable', 'faster', 'cheaper', 'environment', 'healthy', 'friends/family', 'hobby/interest', 'identity/culture', 'more fun']
reasons_to_not_bike = ['weather', 'long/steep', 'don\'t know the way', 'have to carry things', 'don\'t want to sweat', 'not safe for me', 'not safe for my bike', 'feel lazy', 'wouldn\'t be fun', 'too dark']
reason_for_smarthalo = ['navigate', 'keep track of my fitness goals', 'keep track of my environmental goals', 'stay safe', 'keep my bike safe', 'don\'t have to look at my phone', 'it\'s cool!']
accessory_channels = ['Online forums', 'Social media', 'Amazon/e-commerce', 'Chats with friends or family', 'Retail stores']

# output

print("Segment: {}\n===============\n\n".format(segment_text))

output_multi_select_counts(bike_types, segment_df, df, "bike_type")
print("\n")
output_multi_select_counts(companions, segment_df, df, "companions")
print("\n")
output_multi_select_counts(conditions, segment_df, df, "conditions")
print("\n")
output_multi_select_counts(activities, segment_df, df, "activities")
print("\n")
output_multi_select_counts(reasons_to_bike, segment_df, df, "reasons_to_bike")
print("\n")
output_multi_select_counts(reasons_to_not_bike, segment_df, df, "reasons_to_not_bike")
print("\n")
output_multi_select_counts(reason_for_smarthalo, segment_df, df, "reason_for_smarthalo")
print("\n")
output_multi_select_counts(accessory_channels, segment_df, df, "accessory_channels")
# Out:
# Segment: don't have to look at my phone
# ===============
#
#
#              bike_type  all count  segment count  all %  segment %  difference %
# 0            Road bike        743            510  43.94      44.04          0.23
# 1        Mountain bike        495            323  29.27      27.89         -4.71
# 2          Hybrid bike        413            292  24.42      25.22          3.28
# 3      Bike share bike        130             99   7.69       8.55         11.18
# 4               E-bike        261            169  15.43      14.59         -5.44
# 5  Cruiser / City bike        402            276  23.77      23.83          0.25
# 6           Cargo bike         61             40   3.61       3.45         -4.43
# 7    Single-speed bike        158            112   9.34       9.67          3.53
# 8          Gravel bike        189            136  11.18      11.74          5.01
#
#
#                 companions  all count  segment count  all %  segment %  difference %
# 0             I bike alone       1427            987  84.39      85.23          1.00
# 1  With family and friends        708            495  41.87      42.75          2.10
# 2      With young children        159            114   9.40       9.84          4.68
# 3       With a riding pack        129             96   7.63       8.29          8.65
#
#
#   conditions  all count  segment count  all %  segment %  difference %
# 0  Temperate       1581           1091  93.49      94.21          0.77
# 1  Hot/Humid        977            693  57.78      59.84          3.57
# 2       Rain        731            510  43.23      44.04          1.87
# 3   Snow/Ice        318            222  18.81      19.17          1.91
# 4      Night       1014            722  59.96      62.35          3.99
#
#
#          activities  all count  segment count  all %  segment %  difference %
# 0         Commuting        988            699  58.43      60.36          3.30
# 1  Chores / Errands        622            451  36.78      38.95          5.90
# 2              Work        485            328  28.68      28.32         -1.26
# 3    Transportation        928            653  54.88      56.39          2.75
# 4   Mountain biking        332            220  19.63      19.00         -3.21
# 5           Touring        578            418  34.18      36.10          5.62
# 6            Racing        148            101   8.75       8.72         -0.34
# 7           Fitness       1083            754  64.04      65.11          1.67
# 8               BMX          5              5   0.30       0.43         43.33
# 9    Pleasure rides       1307            920  77.29      79.45          2.79
#
#
#     reasons_to_bike  all count  segment count  all %  segment %  difference %
# 0        convenient        724            523  42.81      45.16          5.49
# 1          reliable        426            319  25.19      27.55          9.37
# 2            faster        745            541  44.06      46.72          6.04
# 3           cheaper        684            506  40.45      43.70          8.03
# 4       environment       1009            720  59.67      62.18          4.21
# 5           healthy       1471           1021  86.99      88.17          1.36
# 6    friends/family        440            325  26.02      28.07          7.88
# 7    hobby/interest        881            620  52.10      53.54          2.76
# 8  identity/culture        509            359  30.10      31.00          2.99
# 9          more fun       1076            760  63.63      65.63          3.14
#
#
#     reasons_to_not_bike  all count  segment count  all %  segment %  difference %
# 0               weather       1076            752  63.63      64.94          2.06
# 1            long/steep        506            354  29.92      30.57          2.17
# 2    don't know the way         92             64   5.44       5.53          1.65
# 3  have to carry things        580            418  34.30      36.10          5.25
# 4   don't want to sweat        326            241  19.28      20.81          7.94
# 5       not safe for me        857            609  50.68      52.59          3.77
# 6  not safe for my bike        632            457  37.37      39.46          5.59
# 7             feel lazy        531            384  31.40      33.16          5.61
# 8       wouldn't be fun        325            211  19.22      18.22         -5.20
# 9              too dark        333            239  19.69      20.64          4.82
#
#
#                    reason_for_smarthalo  all count  segment count  all %  segment %  difference %
# 0                              navigate       1337            987  79.07      85.23          7.79
# 1        keep track of my fitness goals        719            514  42.52      44.39          4.40
# 2  keep track of my environmental goals        298            228  17.62      19.69         11.75
# 3                             stay safe        858            636  50.74      54.92          8.24
# 4                     keep my bike safe        873            618  51.63      53.37          3.37
# 5        don't have to look at my phone       1158           1158  68.48     100.00         46.03
# 6                            it's cool!       1173            796  69.37      68.74         -0.91
#
#
#              accessory_channels  all count  segment count  all %  segment %  difference %
# 0                 Online forums        525            360  31.05      31.09          0.13
# 1                  Social media        955            673  56.48      58.12          2.90
# 2             Amazon/e-commerce        492            356  29.10      30.74          5.64
# 3  Chats with friends or family        489            358  28.92      30.92          6.92
# 4                 Retail stores        554            376  32.76      32.47         -0.89
